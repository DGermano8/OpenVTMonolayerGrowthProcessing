# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
from matplotlib.colors import ListedColormap, BoundaryNorm
import csv
from concave_hull import concave_hull, concave_hull_indexes
from shapely.geometry import Polygon

# %%
# import the needed data for each framework

def import_all_simulation_data_for_tissue_size(framework_head, framework_location, optional_key=None):
    # framework = '1000_Data/' +  framework_head +'_MonolayerGrowth_1000_Data/'
    framework = framework_location
    num_files = len([f for f in os.listdir(framework) if os.path.isfile(os.path.join(framework, f))])

    # Aggregate data from all 100 simulations
    total_number_of_cells = []
    tissue_areas = []
    tissue_perimeters = []
    tissue_roughnesses = []


    if framework_head == 'TST' or framework_head == 'Artistoo' or framework_head == 'Morpheus':
        iter_vals = np.arange(0, 46*num_files, 46)
    elif framework_head == 'Chaste':
        iter_vals = range(0, num_files-2)
    else:
        iter_vals = range(0, num_files-1)


    for index in iter_vals:
        if framework_head == 'Artistoo':
            file_path = os.path.join(framework, f'cell_data_no_inhibition_{index:03d}.csv')
        elif framework_head == 'CC3D':
            file_path = os.path.join(framework, f'cell_data_no_inhibition_{index:03d}.csv')
        elif framework_head == 'PhysiCell' or framework_head == 'PolyHoop':
            file_path = os.path.join(framework, f'data{index:06d}.csv')
        else:
            file_path = os.path.join(framework, f'cell_data_no_inhibition_{index}.csv')

        if framework_head == 'Morpheus':
            data = np.loadtxt(file_path, delimiter='\t', skiprows=1)
        elif framework_head == 'CC3D':
            data = np.loadtxt(file_path, delimiter=',', skiprows=1)
        else:
            data = np.loadtxt(file_path, delimiter=',', skiprows=1)
        
        
        if data.ndim == 2:
            number_of_cells = data.shape[0]
        else:
            number_of_cells = 1
            

        if number_of_cells < 3:

            if number_of_cells == 1:
                hull_area = np.pi * data[2]**2
                # hull_perimeter = 2 * np.pi * data[2]

                hull_perimeter = 2 * np.pi * data[2]
                roughness = hull_perimeter / (2*np.pi * np.sqrt(hull_area/np.pi))

                hull_perimeter = np.sqrt(hull_area/np.pi)

            else:
                hull_area = 0
                hull_perimeter = 0
                roughness = 0
                for i in range(number_of_cells):
                    hull_area += np.pi * data[i,2]**2
                    hull_perimeter += 2 * np.pi * data[i,2]
                roughness += hull_perimeter / (2*np.pi * np.sqrt(hull_area/np.pi))
                hull_perimeter = np.sqrt(hull_area/np.pi)

        else:
            x_vals = data[:,0]
            y_vals = data[:,1]

            # create 2D numpy array of points
            points = np.column_stack((x_vals, y_vals))
            hull_indexes = concave_hull_indexes(points, concavity = 1.5, length_threshold = 0.0)
            hull_points = concave_hull(points[hull_indexes])

            # find the area of the concave hull
            hull_polygon = Polygon(hull_points)
            hull_area = hull_polygon.area
            # print(f"Concave hull area: {hull_area}")

            # calculate the length of the concave hull perimeter
            hull_perimeter = hull_polygon.length
            roughness = hull_perimeter / (2*np.pi * np.sqrt(hull_area/np.pi))

            centroid = points.mean(axis=0)

            p1 = hull_points[:-1]
            p2 = hull_points[1:]

            # Midpoint of each edge
            midpoints = 0.5 * (p1 + p2)

            # Length of each edge (the weight)
            edge_lengths = np.linalg.norm(p2 - p1, axis=1)

            # Distance from centroid to each edge midpoint
            mid_distances = np.linalg.norm(midpoints - centroid, axis=1)

            # Weighted average
            radius = np.sum(mid_distances * edge_lengths) / np.sum(edge_lengths)
            
            hull_perimeter = radius
            
            # print(f"Roughness: {roughness}")

        total_number_of_cells.append(number_of_cells)
        tissue_areas.append(hull_area)
        tissue_perimeters.append(hull_perimeter)
        tissue_roughnesses.append(roughness)
    return total_number_of_cells, tissue_areas, tissue_perimeters, tissue_roughnesses

# %%
head = "/Users/dger0683/ChasteWorkspace/chaste_output/New/NoInhibition_strong_100"
key = "quadratic"
iteration = "MonolayerGrowth_Beta_Index0"


data_rad_file = f"{head}/{key}/{iteration}/results_from_time_0/celldata_Radius.dat"
if not os.path.isfile(data_rad_file):
    print(f"Data file {data_rad_file} not found.")
    sys.exit(1)

data_list = []
radius_iter = 0
radius_growth = []
time_points = []
with open(data_rad_file, 'r') as f:
    for line in f:
        line = line.strip()
        if line:  # skip empty lines
            radius_iter = radius_iter + 1
            row = list(map(float, line.split()))
            data_list.append((len(row)-1)/5)
            time_points.append(row[0])


# now we will do the time conversion from absolute time to a relative time.
dt = 0.002
sample_rate = 0.25/dt
final_area = 2.0
growth_rate = 0.2
generation_cycle_time = 0.5*final_area/growth_rate
# time_points = time_points * dt * sample_rate

# time_points[-1] = 51.432
time_points = np.array(time_points) / generation_cycle_time

plt.figure(figsize=(8,4))
plt.plot(time_points, data_list, label='Chaste', color='blue')
plt.xlabel('Mean Generational Cycle Time')
plt.ylabel('Number of Cells')
plt.title('Monolayer Cell Count Through Time') 
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
PhysiCell_data = import_all_simulation_data_for_tissue_size('PhysiCell','Tissue_Size/timeseries_1K_PhysiCell/')

PhysiCell_time_points = np.arange(len(PhysiCell_data))

dt = 0.1
sample_rate = 500
final_area = 78.54
growth_rate = 0.002265
final_time =  4883
generation_cycle_time = 0.5*final_area/(growth_rate/dt)

generation_cycle_time = 441.5

print(f"Generation Cycle Time: {generation_cycle_time}")

PhysiCell_time_points = PhysiCell_time_points * dt * sample_rate
PhysiCell_time_points[-1] = final_time
PhysiCell_time_points = PhysiCell_time_points / generation_cycle_time

# PhysiCell_time_points = PhysiCell_time_points / max(PhysiCell_time_points)

plt.figure(figsize=(6,4))
plt.plot(PhysiCell_time_points, PhysiCell_data, label='PhysiCell', color='green')
plt.plot(time_points, data_list, label='Chaste', color='blue', linestyle='--')

# plot the theoretical exponential growth curve for reference
theoretical_time_points = np.linspace(0, 10, 10)
theoretical_cell_counts = np.exp(theoretical_time_points * np.log(2))
plt.plot(theoretical_time_points, theoretical_cell_counts, label='Theoretical Exponential Growth', color='red', linestyle=':')

plt.xlabel('Mean Generational Time')
plt.ylabel('Number of Cells')
plt.title('Monolayer Cell Count Through Time')
plt.legend()
plt.grid(True)
plt.tight_layout()
# log scale for y-axis to better visualize growth
plt.yscale('log')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 PhysiCell_data = import_all_simulation_data_for_tissue_size('PhysiCell','Tissue_Size/timeseries_1K_PhysiCell/')
#       3 PhysiCell_time_points = np.arange(len(PhysiCell_data))
#       5 dt = 0.1
#
# Cell In[2], line 38, in import_all_simulation_data_for_tissue_size(framework_head, framework_location, optional_key)
#      36     data = np.loadtxt(file_path, delimiter=',', skiprows=1)
#      37 else:
# ---> 38     data = np.loadtxt(file_path, delimiter=',', skiprows=1)
#      41 if data.ndim == 2:
#      42     number_of_cells = data.shape[0]
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/numpy/lib/_npyio_impl.py:1397, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1394 if isinstance(delimiter, bytes):
#    1395     delimiter = delimiter.decode('latin1')
# -> 1397 arr = _read(fname, dtype=dtype, comment=comment, delimiter=delimiter,
#    1398             converters=converters, skiplines=skiprows, usecols=usecols,
#    1399             unpack=unpack, ndmin=ndmin, encoding=encoding,
#    1400             max_rows=max_rows, quote=quotechar)
#    1402 return arr
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/numpy/lib/_npyio_impl.py:1012, in _read(fname, delimiter, comment, quote, imaginary_unit, usecols, skiplines, max_rows, converters, ndmin, unpack, dtype, encoding)
#    1010     fname = os.fspath(fname)
#    1011 if isinstance(fname, str):
# -> 1012     fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#    1013     if encoding is None:
#    1014         encoding = getattr(fh, 'encoding', 'latin1')
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/numpy/lib/_datasource.py:192, in open(path, mode, destpath, encoding, newline)
#     155 """
#     156 Open `path` with `mode` and return the file object.
#     157
#    (...)
#     188
#     189 """
#     191 ds = DataSource(destpath)
# --> 192 return ds.open(path, mode, encoding=encoding, newline=newline)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/numpy/lib/_datasource.py:529, in DataSource.open(self, path, mode, encoding, newline)
#     526     return _file_openers[ext](found, mode=mode,
#     527                               encoding=encoding, newline=newline)
#     528 else:
# --> 529     raise FileNotFoundError(f"{path} not found.")
#
# FileNotFoundError: Tissue_Size/timeseries_1K_PhysiCell/data000000.csv not found.

# %%
def import_data_files_for_timeseries_plots(index, key, file_index):

    head = "/Users/dger0683/ChasteWorkspace/chaste_output/New/NoInhibition_strong_100/"

    # import the data file : results.viznodes. 
    # data_rad_file = f"{head}/{key}/MonolayerGrowth_Beta_Index{index}/results_from_time_0/cellareas.dat"
    data_rad_file = f"{head}/{key}/MonolayerGrowth_Beta_Index{index}/results_from_time_0/celldata_Radius.dat"
    if not os.path.isfile(data_rad_file):
        print(f"Data file {data_rad_file} not found.")
        sys.exit(1)

    data_surf_file = f"{head}/{key}/MonolayerGrowth_Beta_Index{index}/results_from_time_0/celldata_FreeSurfaceFraction.dat"
    if not os.path.isfile(data_surf_file):
        print(f"Data file {data_surf_file} not found.")
        sys.exit(1)

    data_area_file = f"{head}/{key}/MonolayerGrowth_Beta_Index{index}/results_from_time_0/celldata_FreeAreaFraction.dat"
    if not os.path.isfile(data_area_file):
        print(f"Data file {data_area_file} not found.")
        sys.exit(1)

    inhibited_growth_file = f"{head}/{key}/MonolayerGrowth_Beta_Index{index}/results_from_time_0/celldata_growth inhibited.dat"
    if not os.path.isfile(inhibited_growth_file):
        print(f"Data file {inhibited_growth_file} not found.")
        sys.exit(1)
    # extract the relavent data from the files
    # open the loggedcell.dat file, and go straight to the last row
    data_list = []
    with open(data_rad_file, 'r') as f:
        for line in f:
            line = line.strip()
            if line:  # skip empty lines
                row = list(map(float, line.split()))
                data_list.append(row)

    final_row = data_list[file_index][1:]
    # print(f"Final row (excluding time): {final_row}")
    x_vals = final_row[2::5]
    y_vals = final_row[3::5]
    r_vals = final_row[4::5]
    # for i in range(len(r_vals)):
    #     r_vals[i] = np.sqrt(r_vals[i]/np.pi)

    data_surf = []
    with open(data_surf_file, 'r') as f:
        for line in f:
            line = line.strip()
            if line:  # skip empty lines
                row = list(map(float, line.split()))
                data_surf.append(row)
    surface_fractions = data_surf[file_index][5::5]


    data_area = []
    with open(data_area_file, 'r') as f:
        for line in f:
            line = line.strip()
            if line:  # skip empty lines
                row = list(map(float, line.split()))
                data_area.append(row)
    area_fractions = data_area[file_index][5::5]

    data_inhibited = []
    with open(inhibited_growth_file, 'r') as f:
        for line in f:
            line = line.strip()
            if line:  # skip empty lines
                row = list(map(float, line.split()))
                data_inhibited.append(row)
    inhibited_cells = data_inhibited[file_index][5::5]

    time_point = data_list[file_index][0]

    return x_vals, y_vals, r_vals, surface_fractions, area_fractions, inhibited_cells, time_point

# %%
# I want to reprocess all the files titled time_series_data.csv in the CHASTE_MonolayerGrowth_1000_Datas folder.
# In doing so, I want to create a new file titled "tmeline.txt" that contains the points for that given simulation, 
# but scalled by the generation cycle time.

for sim_index in range(100):

    read_csv_file = f'timeSeries/CHASTE_MonolayerGrowth_1000_Data/Sim_{sim_index}/time_series_data.csv'
    t = []
    with open(read_csv_file, mode='r') as file:
        reader = csv.reader(file)
        for row in reader:
            if row[1] == 'time_point':
                continue  # Skip the header row
            else:
                t.append(float(row[1]))

    dt = 0.002
    sample_rate = 0.25/dt
    final_area = 2.0
    growth_rate = 0.2
    generation_cycle_time = 0.5*final_area/growth_rate

    t = np.array(t) / generation_cycle_time

    output_file = f'timeSeries/CHASTE_MonolayerGrowth_1000_Data/Sim_{sim_index}/timeline.txt'
    with open(output_file, mode='w') as file:
        writer = csv.writer(file)
        # create a header row
        writer.writerow(['index', 'time'])
        for i, time_point in enumerate(t):
            writer.writerow([f"{i} {time_point}"])

# %%
# import csv
# # iterate through all indices and collate the data

# for index in range(80, 100):
#     all_x_vals = []
#     all_y_vals = []
#     all_r_vals = []
#     all_surface_fractions = []
#     all_area_fractions = []
#     all_inhibited_cells = []
#     all_time_points = []
#     for file_index in range(250):
#         try:
#             # x_vals, y_vals, r_vals, surface_fractions, area_fractions, inhibited_cells = import_data_files_for_histograms(index, "100")
#             x_vals, y_vals, r_vals, surface_fractions, area_fractions, inhibited_cells, time_point = import_data_files_for_timeseries_plots(index, "quadratic", file_index)
#             all_x_vals.extend(x_vals)
#             all_y_vals.extend(y_vals)
#             all_r_vals.extend(r_vals)
#             all_surface_fractions.extend(surface_fractions)
#             all_area_fractions.extend(area_fractions)
#             all_inhibited_cells.extend(inhibited_cells)
#             all_time_points.append(time_point)

#             output_file = f'CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_{index}/cell_data_no_inhibition_{file_index}.csv'
#             # check if output folder exists, if not create it
#             output_folder = os.path.dirname(output_file)
#             if not os.path.exists(output_folder):
#                 os.makedirs(output_folder)
#             with open(output_file, mode='w', newline='') as file:
#                 writer = csv.writer(file)
#                 writer.writerow(['x_pos', 'y_pos', 'radius_i', 'f_i', 'a_i'])
#                 for x, y, r, sf, af in zip(x_vals, y_vals, r_vals, surface_fractions, area_fractions):
#                     writer.writerow([x, y, r, sf, af])
#             print(f"Data exported to {output_file}")
#         except Exception as e:
#             print(f"Error occurred while processing file {file_index} for index {index}")
        
#     # now we export the time series data for this index
#     time_series_output_file = f'CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_{index}/time_series_data.csv'
#     with open(time_series_output_file, mode='w', newline='') as file:
#         writer = csv.writer(file)
#         writer.writerow(['simulation point', 'time_point'])
#         for n, t in enumerate(all_time_points):
#             writer.writerow([n, t])
#     print(f"Time series data exported to {time_series_output_file}")

# print(f"Total number of cells across all simulations: {len(all_x_vals)}")
# Out:
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_0.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_1.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_2.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_3.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_4.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_5.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_6.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_7.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_8.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_9.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_10.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_11.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_12.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_13.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_14.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_15.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_16.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_17.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_18.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_19.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_20.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_21.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_22.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_23.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_24.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_25.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_26.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_27.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_28.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_29.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_30.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_31.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_32.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_33.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_34.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_35.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_36.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_37.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_38.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_39.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_40.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_41.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_42.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_43.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_44.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_45.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_46.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_47.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_48.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_49.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_50.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_51.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_52.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_53.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_54.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_55.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_56.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_57.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_58.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_59.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_60.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_61.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_62.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_63.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_64.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_65.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_66.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_67.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_68.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_69.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_70.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_71.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_72.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_73.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_74.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_75.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_76.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_77.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_78.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_79.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_80.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_81.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_82.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_83.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_84.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_85.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_86.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_87.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_88.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_89.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_90.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_91.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_92.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_93.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_94.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_95.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_96.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_97.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_98.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_99.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_100.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_101.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_102.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_103.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_104.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_105.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_106.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_107.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_108.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_109.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_110.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_111.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_112.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_113.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_114.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_115.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_116.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_117.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_118.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_119.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_120.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_121.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_122.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_123.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_124.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_125.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_126.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_127.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_128.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_129.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_130.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_131.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_132.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_133.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_134.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_135.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_136.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_137.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_138.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_139.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_140.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_141.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_142.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_143.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_144.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_145.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_146.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_147.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_148.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_149.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_150.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_151.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_152.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_153.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_154.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_155.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_156.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_157.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_158.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_159.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_160.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_161.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_162.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_163.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_164.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_165.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_166.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_167.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_168.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_169.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_170.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_171.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_172.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_173.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_174.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_175.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_176.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_177.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_178.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_179.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_180.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_181.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_182.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_183.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_184.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_185.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_186.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_187.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_188.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_189.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_190.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_191.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_192.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_193.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_194.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_195.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_196.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_197.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_198.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_199.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_200.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_201.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_202.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_203.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_204.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_205.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_206.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_207.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_208.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_209.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_210.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_211.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_212.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_213.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_214.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_215.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_80/cell_data_no_inhibition_216.csv
# Error occurred while processing file 217 for index 80
# Error occurred while processing file 218 for index 80
# Error occurred while processing file 219 for index 80
# Error occurred while processing file 220 for index 80
# Error occurred while processing file 221 for index 80
# Error occurred while processing file 222 for index 80
# Error occurred while processing file 223 for index 80
# Error occurred while processing file 224 for index 80
# Error occurred while processing file 225 for index 80
# Error occurred while processing file 226 for index 80
# Error occurred while processing file 227 for index 80
# Error occurred while processing file 228 for index 80
# Error occurred while processing file 229 for index 80
# Error occurred while processing file 230 for index 80
# Error occurred while processing file 231 for index 80
# Error occurred while processing file 232 for index 80
# Error occurred while processing file 233 for index 80
# Error occurred while processing file 234 for index 80
# Error occurred while processing file 235 for index 80
exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_81/time_series_data.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_82/cell_data_no_inhibition_0.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_82/cell_data_no_inhibition_1.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_82/cell_data_no_inhibition_2.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_82/cell_data_no_inhibition_3.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_82/cell_data_no_inhibition_4.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_82/cell_data_no_inhibition_5.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_82/cell_data_no_inhibition_6.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_82/cell_data_no_inhibition_7.csv
# ...
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_89.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_90.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_91.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_92.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_93.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_94.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_95.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_96.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_97.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_98.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_99.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_100.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_101.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_102.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_103.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_104.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_105.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_106.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_107.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_108.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_109.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_110.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_111.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_112.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_113.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_114.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_115.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_116.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_117.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_118.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_119.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_120.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_121.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_122.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_123.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_124.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_125.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_126.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_127.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_128.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_129.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_130.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_131.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_132.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_133.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_134.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_135.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_136.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_137.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_138.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_139.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_140.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_141.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_142.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_143.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_144.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_145.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_146.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_147.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_148.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_149.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_150.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_151.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_152.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_153.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_154.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_155.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_156.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_157.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_158.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_159.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_160.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_161.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_162.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_163.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_164.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_165.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_166.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_167.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_168.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_169.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_170.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_171.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_172.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_173.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_174.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_175.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_176.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_177.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_178.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_179.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_180.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_181.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_182.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_183.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_184.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_185.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_186.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_187.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_188.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_189.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_190.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_191.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_192.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_193.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_194.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_195.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_196.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_197.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_198.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_199.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_200.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_201.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_202.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_203.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_204.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_205.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_206.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_207.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_208.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_209.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_210.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_211.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_212.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_213.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/cell_data_no_inhibition_214.csv
# Error occurred while processing file 215 for index 89
# Error occurred while processing file 216 for index 89
# Error occurred while processing file 217 for index 89
# Error occurred while processing file 218 for index 89
# Error occurred while processing file 219 for index 89
# Error occurred while processing file 220 for index 89
# Error occurred while processing file 221 for index 89
# Error occurred while processing file 222 for index 89
# Error occurred while processing file 223 for index 89
# Error occurred while processing file 224 for index 89
# Error occurred while processing file 225 for index 89
# Error occurred while processing file 226 for index 89
# Error occurred while processing file 227 for index 89
# Error occurred while processing file 228 for index 89
# Error occurred while processing file 229 for index 89
# Error occurred while processing file 230 for index 89
# Error occurred while processing file 231 for index 89
# Error occurred while processing file 232 for index 89
# Error occurred while processing file 233 for index 89
# Error occurred while processing file 234 for index 89
# Error occurred while processing file 235 for index 89
# Error occurred while processing file 236 for index 89
# Error occurred while processing file 237 for index 89
# Error occurred while processing file 238 for index 89
# Error occurred while processing file 239 for index 89
# Error occurred while processing file 240 for index 89
# Error occurred while processing file 241 for index 89
# Error occurred while processing file 242 for index 89
# Error occurred while processing file 243 for index 89
# Error occurred while processing file 244 for index 89
# Error occurred while processing file 245 for index 89
# Error occurred while processing file 246 for index 89
# Error occurred while processing file 247 for index 89
# Error occurred while processing file 248 for index 89
# Error occurred while processing file 249 for index 89
# Time series data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_89/time_series_data.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_90/cell_data_no_inhibition_0.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_90/cell_data_no_inhibition_1.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_90/cell_data_no_inhibition_2.csv
# Data exported to CHASTE_MonolayerGrowth_1000_Data_TimeSeries/Sim_90/cell_data_no_inhibition_3.csv
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 15
#      12 for file_index in range(250):
#      13     try:
#      14         # x_vals, y_vals, r_vals, surface_fractions, area_fractions, inhibited_cells = import_data_files_for_histograms(index, "100")
# ---> 15         x_vals, y_vals, r_vals, surface_fractions, area_fractions, inhibited_cells, time_point = import_data_files_for_timeseries_plots(index, "quadratic", file_index)
#      16         all_x_vals.extend(x_vals)
#      17         all_y_vals.extend(y_vals)
#
# Cell In[5], line 49, in import_data_files_for_timeseries_plots(index, key, file_index)
#      47         line = line.strip()
#      48         if line:  # skip empty lines
# ---> 49             row = list(map(float, line.split()))
#      50             data_surf.append(row)
#      51 surface_fractions = data_surf[file_index][5::5]
#
# KeyboardInterrupt:

# %%
def clean_time_series_data_and_calculate_mean(framework, directory):
    # 1) Load + store all simulation data (no plotting here)
    simulation_data = []

    if framework == 'Chaste':
        final_area = 2.0
        final_radius = np.sqrt(final_area/np.pi)
    else:
        final_area = 1
        final_radius = 1

    for sim_index in range(100):
        print(f"Processing simulation {sim_index} for framework {framework}...")
        if framework == 'Chaste':
            number_of_cells, tissue_areas, tissue_perimeters, tissue_roughnesses = import_all_simulation_data_for_tissue_size(
                framework,
                f'{directory}/Sim_{sim_index}/'
            )
            read_csv_file = f'{directory}/Sim_{sim_index}/timeline.txt'
        elif framework == 'TST':
            number_of_cells, tissue_areas, tissue_perimeters, tissue_roughnesses = import_all_simulation_data_for_tissue_size(
                framework,
                f'{directory}/run{sim_index+1}/'
            )
            # t = np.arange(0, len(number_of_cells), 46)
            # t = t / 183.0
        else:
            number_of_cells, tissue_areas, tissue_perimeters, tissue_roughnesses = import_all_simulation_data_for_tissue_size(
                framework,
                f'{directory}/run{sim_index+1}/'
            )
            read_csv_file = f'{directory}/run{sim_index+1}/timeline.txt'

        if framework != 'TST':
            t = []
            with open(read_csv_file, mode='r') as file:
                reader = csv.reader(file)
                next(reader)  # header
                for row in reader:
                    row_i = row[0].strip().split()
                    t.append(float(row_i[1]))

            t = np.array(t)
        elif framework == 'TST':
            t = np.arange(0, 46*len(number_of_cells), 46)
            t = t / (183.0 * 5.0)

        # "relative" versions (normalized by first value) for averaging shape across sims
        cells_rel = np.array(number_of_cells)
        # areas_rel = np.array(tissue_areas) / tissue_areas[0]
        # perims_rel = np.array(tissue_perimeters) / tissue_perimeters[0]
        # rough_rel = np.array(tissue_roughnesses) / tissue_roughnesses[0]
        areas_rel = np.array(tissue_areas)
        perims_rel = np.array(tissue_perimeters)
        rough_rel = np.array(tissue_roughnesses)
        # areas_rel = np.array(tissue_areas)/final_area
        # perims_rel = np.array(tissue_perimeters)/final_radius
        # rough_rel = np.array(tissue_roughnesses)

        # find the first time that number of cells is 2
        first_time_2_cells = None
        time_to_4_cells = None
        for i, num_cells in enumerate(cells_rel):
            if num_cells > 1 and first_time_2_cells is None:
                first_time_2_cells = i - 1
            elif num_cells > 3 and time_to_4_cells is None:
                time_to_4_cells = i
                break
        prefered_area = tissue_areas[first_time_2_cells]

        # now set everything before time_to_4_cells to nan
        for i in range(time_to_4_cells):
            tissue_areas[i] = np.nan
            tissue_perimeters[i] = np.nan
            tissue_roughnesses[i] = np.nan

            areas_rel[i] = np.nan
            perims_rel[i] = np.nan
            rough_rel[i] = np.nan

        simulation_data.append({
            "time": t,
            "cells": np.array(number_of_cells),
            "areas": np.array(tissue_areas),
            "perims": np.array(tissue_perimeters),
            "rough": np.array(tissue_roughnesses),
            "cells_rel": cells_rel,
            "areas_rel": areas_rel,
            "perims_rel": perims_rel,
            "rough_rel": rough_rel,
            "prefered_area": prefered_area
        })

    
    # Optional: save for reuse (skip recomputation next time)
    # np.savez("chaste_timeseries_cache.npz", simulation_data=np.array(simulation_data, dtype=object))

    # scale the raw data by the prefered area for each simulation
    mean_prefered_area = np.mean([d["prefered_area"] for d in simulation_data])
    for d in simulation_data:
        d["areas_rel"] = d["areas_rel"] / mean_prefered_area
        d["perims_rel"] = d["perims_rel"] / np.sqrt(mean_prefered_area/np.pi)

    # 2) Align to a common relative-time grid so averages are valid
    t_min = max(d["time"].min() for d in simulation_data)
    t_max = min(d["time"].max() for d in simulation_data)
    print(f"Common time range across simulations: {t_min} to {t_max}")
    common_t = np.linspace(t_min, t_max, 300)

    cells_rel_mat = np.vstack([np.interp(common_t, d["time"], d["cells_rel"]) for d in simulation_data])
    areas_rel_mat = np.vstack([np.interp(common_t, d["time"], d["areas_rel"]) for d in simulation_data])
    perims_rel_mat = np.vstack([np.interp(common_t, d["time"], d["perims_rel"]) for d in simulation_data])
    rough_rel_mat = np.vstack([np.interp(common_t, d["time"], d["rough_rel"]) for d in simulation_data])


    cells_rel_mean = cells_rel_mat.mean(axis=0)
    areas_rel_mean = areas_rel_mat.mean(axis=0) #/mean_prefered_area
    perims_rel_mean = perims_rel_mat.mean(axis=0) #/ np.sqrt(mean_prefered_area/np.pi)
    rough_rel_mean = rough_rel_mat.mean(axis=0)

    return common_t, cells_rel_mean, areas_rel_mean, perims_rel_mean, rough_rel_mean, simulation_data

# %%
from scipy.stats import wasserstein_distance

def wasserstein_from_timeseries(t1, y1, t2, y2):
    """
    Wasserstein-1 distance between two monotonic time series on different grids.

    Each series is treated as a 1D distribution over y-values, where the
    normalised time steps act as the probability weights.

    Args:
        t1, y1: time and values for series 1 (each length N, monotonic)
        t2, y2: time and values for series 2 (each length M, monotonic)

    Returns:
        Scalar Wasserstein-1 distance.
    """
    t1, y1 = np.asarray(t1, dtype=float), np.asarray(y1, dtype=float)
    t2, y2 = np.asarray(t2, dtype=float), np.asarray(y2, dtype=float)

    # Normalise each time grid independently to [0, 1]
    def time_weights(t):
        t_norm = (t - t[0]) / (t[-1] - t[0])
        return np.diff(t_norm, prepend=t_norm[0])

    return wasserstein_distance(y1, y2, u_weights=time_weights(t1),
                                        v_weights=time_weights(t2))

# %%
from matplotlib.colors import to_rgb


# 3) Plot all stored curves + average curve
fig, axs = plt.subplots(2, 2, figsize=(12, 9), sharex=True)
(ax_cells, ax_areas), (ax_perimeters, ax_roughness) = axs

ax_cells.set_title("Number of Cells", fontsize=16)
ax_areas.set_title("Relative Tissue Area", fontsize=16)
ax_perimeters.set_title("Relative Tissue Radius", fontsize=16)
ax_roughness.set_title("Relative Tissue Roughness", fontsize=16)


ax_cells.set_ylabel("Number of Cells", fontsize=14)
ax_areas.set_ylabel("Relative Tissue Area", fontsize=14)
ax_perimeters.set_ylabel("Relative Tissue Radius", fontsize=14)
ax_roughness.set_ylabel("Relative Tissue Roughness", fontsize=14)

ax_perimeters.set_xlabel("Mean Generational Time", fontsize=14)
ax_roughness.set_xlabel("Mean Generational Time", fontsize=14)

colors =[ (248/255, 218/255, 152/255),
          (189/255, 85/255, 34/255),
          (0/255, 0/255, 0/255),
          (100/255, 180/255, 194/255)]
framework_labels = ['Chaste', 'PhysiCell', 'PolyHoop', 'TST']
# framework_labels = ['TST']

iteration = 0
for framework in framework_labels:
    common_t, cells_rel_mean, areas_rel_mean, perims_rel_mean, rough_rel_mean, _ = clean_time_series_data_and_calculate_mean(framework, f'data/timeSeries/{framework}_MonolayerGrowth_1000_Data/')

    # mean curves
    ax_cells.plot(common_t, cells_rel_mean, color=colors[iteration], linewidth=2, label=framework_labels[iteration])
    ax_areas.plot(common_t, areas_rel_mean, color=colors[iteration], linewidth=2, label=framework_labels[iteration])
    ax_perimeters.plot(common_t, perims_rel_mean, color=colors[iteration], linewidth=2, label=framework_labels[iteration])
    ax_roughness.plot(common_t, rough_rel_mean, color=colors[iteration], linewidth=2, label=framework_labels[iteration])
    iteration += 1

# theoretical relative doubling curve (starts at 1)
theoretical_time_points = np.linspace(0, 10, 200)
theoretical_cell_counts = np.exp(theoretical_time_points * np.log(2))
theoretical_area = 2**(theoretical_time_points)  # area grows with the square of the radius, which grows with the number of cells
theoretical_perimeter =  2**(theoretical_time_points/2)  # perimeter grows linearly with the radius, which grows with the number of cells

ax_cells.plot(theoretical_time_points, theoretical_cell_counts, color='red', linestyle=':', label='Theoretical')
ax_areas.plot(theoretical_time_points, theoretical_area, color='red', linestyle=':', label='Theoretical')
ax_perimeters.plot(theoretical_time_points, theoretical_perimeter, color='red', linestyle=':', label='Theoretical')

for ax in [ax_cells, ax_areas, ax_perimeters, ax_roughness]:
    ax.grid(True)
    ax.legend()
    # font size of legend
    ax.legend(fontsize=12)

ax_cells.set_yscale('log')
ax_areas.set_yscale('log')
ax_perimeters.set_yscale('log')

# make all axis ticks font size 16
for ax in [ax_cells, ax_areas, ax_perimeters, ax_roughness]:
    ax.tick_params(axis='both', which='major', labelsize=12)

plt.tight_layout()
plt.show()
# Out:
# Processing simulation 0 for framework Chaste...
# Processing simulation 1 for framework Chaste...
# Processing simulation 2 for framework Chaste...
# Processing simulation 3 for framework Chaste...
# Processing simulation 4 for framework Chaste...
# Processing simulation 5 for framework Chaste...
# Processing simulation 6 for framework Chaste...
# Processing simulation 7 for framework Chaste...
# Processing simulation 8 for framework Chaste...
# Processing simulation 9 for framework Chaste...
# Common time range across simulations: 0.0 to 10.2864
# Processing simulation 0 for framework PhysiCell...
# Processing simulation 1 for framework PhysiCell...
# Processing simulation 2 for framework PhysiCell...
# Processing simulation 3 for framework PhysiCell...
# Processing simulation 4 for framework PhysiCell...
# Processing simulation 5 for framework PhysiCell...
# Processing simulation 6 for framework PhysiCell...
# Processing simulation 7 for framework PhysiCell...
# Processing simulation 8 for framework PhysiCell...
# Processing simulation 9 for framework PhysiCell...
# Common time range across simulations: 0.0 to 11.003382
# Processing simulation 0 for framework PolyHoop...
# Processing simulation 1 for framework PolyHoop...
# Processing simulation 2 for framework PolyHoop...
# Processing simulation 3 for framework PolyHoop...
# Processing simulation 4 for framework PolyHoop...
# Processing simulation 5 for framework PolyHoop...
# Processing simulation 6 for framework PolyHoop...
# Processing simulation 7 for framework PolyHoop...
# Processing simulation 8 for framework PolyHoop...
# Processing simulation 9 for framework PolyHoop...
# Common time range across simulations: 0.0 to 10.1056
# Processing simulation 0 for framework TST...
# Processing simulation 1 for framework TST...
# Processing simulation 2 for framework TST...
# Processing simulation 3 for framework TST...
# Processing simulation 4 for framework TST...
# Processing simulation 5 for framework TST...
# Processing simulation 6 for framework TST...
# Processing simulation 7 for framework TST...
# Processing simulation 8 for framework TST...
# Processing simulation 9 for framework TST...
# Common time range across simulations: 0.0 to 10.205464480874317

# %%
from matplotlib.colors import to_rgb


# 3) Plot all stored curves + average curve
fig, axs = plt.subplots(2, 2, figsize=(12, 9), sharex=True)
(ax_cells, ax_areas), (ax_perimeters, ax_roughness) = axs

ax_cells.set_title("Number of Cells", fontsize=16)
ax_areas.set_title("Relative Tissue Area", fontsize=16)
ax_perimeters.set_title("Relative Tissue Radius", fontsize=16)
ax_roughness.set_title("Relative Tissue Roughness", fontsize=16)


ax_cells.set_ylabel("Number of Cells", fontsize=14)
ax_areas.set_ylabel("Relative Tissue Area", fontsize=14)
ax_perimeters.set_ylabel("Relative Tissue Radius", fontsize=14)
ax_roughness.set_ylabel("Relative Tissue Roughness", fontsize=14)

ax_perimeters.set_xlabel("Mean Generational Time", fontsize=14)
ax_roughness.set_xlabel("Mean Generational Time", fontsize=14)

colors =[ (248/255, 218/255, 152/255),
          (189/255, 85/255, 34/255),
          (0/255, 0/255, 0/255),
          (100/255, 180/255, 194/255)]
framework_labels = ['Chaste', 'PhysiCell', 'PolyHoop', 'TST']

iteration = 0
for framework in framework_labels:
    common_t, cells_rel_mean, areas_rel_mean, perims_rel_mean, rough_rel_mean, simulation_data = clean_time_series_data_and_calculate_mean(framework, f'data/timeSeries/{framework}_MonolayerGrowth_1000_Data/')

    for sim_index, sim_data in enumerate(simulation_data):
        # plot the raw curves for this simulation with low alpha
        ax_cells.plot(sim_data["time"], sim_data["cells_rel"], color=colors[iteration], alpha=0.15)
        ax_areas.plot(sim_data["time"], sim_data["areas_rel"], color=colors[iteration], alpha=0.15)
        ax_perimeters.plot(sim_data["time"], sim_data["perims_rel"], color=colors[iteration], alpha=0.15)
        ax_roughness.plot(sim_data["time"], sim_data["rough_rel"], color=colors[iteration], alpha=0.15)
    
    # mean curves
    ax_cells.plot(common_t, cells_rel_mean, color=colors[iteration], linewidth=2, label=framework_labels[iteration])
    ax_areas.plot(common_t, areas_rel_mean, color=colors[iteration], linewidth=2, label=framework_labels[iteration])
    ax_perimeters.plot(common_t, perims_rel_mean, color=colors[iteration], linewidth=2, label=framework_labels[iteration])
    ax_roughness.plot(common_t, rough_rel_mean, color=colors[iteration], linewidth=2, label=framework_labels[iteration])
    iteration += 1

# theoretical relative doubling curve (starts at 1)
theoretical_time_points = np.linspace(0, 10, 200)
theoretical_cell_counts = np.exp(theoretical_time_points * np.log(2))
theoretical_area = 2**(theoretical_time_points)  # area grows with the square of the radius, which grows with the number of cells
theoretical_perimeter =  2**(theoretical_time_points/2)  # perimeter grows linearly with the radius, which grows with the number of cells

ax_cells.plot(theoretical_time_points, theoretical_cell_counts, color='red', linestyle=':', label='Theoretical')
ax_areas.plot(theoretical_time_points, theoretical_area, color='red', linestyle=':', label='Theoretical')
ax_perimeters.plot(theoretical_time_points, theoretical_perimeter, color='red', linestyle=':', label='Theoretical')

for ax in [ax_cells, ax_areas, ax_perimeters, ax_roughness]:
    ax.grid(True)
    ax.legend()
    # font size of legend
    ax.legend(fontsize=12)

ax_cells.set_yscale('log')
ax_areas.set_yscale('log')
ax_perimeters.set_yscale('log')

# make all axis ticks font size 16
for ax in [ax_cells, ax_areas, ax_perimeters, ax_roughness]:
    ax.tick_params(axis='both', which='major', labelsize=12)

plt.tight_layout()
plt.show()
# Out:
# Processing simulation 0 for framework Chaste...
# Processing simulation 1 for framework Chaste...
# Processing simulation 2 for framework Chaste...
# Processing simulation 3 for framework Chaste...
# Processing simulation 4 for framework Chaste...
# Processing simulation 5 for framework Chaste...
# Processing simulation 6 for framework Chaste...
# Processing simulation 7 for framework Chaste...
# Processing simulation 8 for framework Chaste...
# Processing simulation 9 for framework Chaste...
# Common time range across simulations: 0.0 to 10.2864
# Processing simulation 0 for framework PhysiCell...
# Processing simulation 1 for framework PhysiCell...
# Processing simulation 2 for framework PhysiCell...
# Processing simulation 3 for framework PhysiCell...
# Processing simulation 4 for framework PhysiCell...
# Processing simulation 5 for framework PhysiCell...
# Processing simulation 6 for framework PhysiCell...
# Processing simulation 7 for framework PhysiCell...
# Processing simulation 8 for framework PhysiCell...
# Processing simulation 9 for framework PhysiCell...
# Common time range across simulations: 0.0 to 11.003382
# Processing simulation 0 for framework PolyHoop...
# Processing simulation 1 for framework PolyHoop...
# Processing simulation 2 for framework PolyHoop...
# Processing simulation 3 for framework PolyHoop...
# Processing simulation 4 for framework PolyHoop...
# Processing simulation 5 for framework PolyHoop...
# Processing simulation 6 for framework PolyHoop...
# Processing simulation 7 for framework PolyHoop...
# Processing simulation 8 for framework PolyHoop...
# Processing simulation 9 for framework PolyHoop...
# Common time range across simulations: 0.0 to 10.1056
# Processing simulation 0 for framework TST...
# Processing simulation 1 for framework TST...
# Processing simulation 2 for framework TST...
# Processing simulation 3 for framework TST...
# Processing simulation 4 for framework TST...
# Processing simulation 5 for framework TST...
# Processing simulation 6 for framework TST...
# Processing simulation 7 for framework TST...
# Processing simulation 8 for framework TST...
# Processing simulation 9 for framework TST...
# Common time range across simulations: 0.0 to 10.205464480874317

# %%
# simulate a theoretical stochastic growth curve using a simple birth process with a given growth rate
def simulate_stochastic_growth(mean_growth_time, total_time):
    number_of_cells = [1]
    growth_time = [np.random.normal(mean_growth_time, 0.4**2,1)[0]]
    time_points = [0]
    t = 0
    while t < total_time:
        current_cells = number_of_cells[-1]
        
        growth_time_arr = np.asarray(growth_time, dtype=float).ravel()
        min_time_index = int(np.argmin(growth_time_arr))
        min_time = growth_time_arr[min_time_index]

        new_time = 0
        while new_time <= 0.0:
            new_time = np.random.normal(mean_growth_time, 0.4**2,1)[0]
        growth_time[min_time_index] = new_time + min_time
        new_time = 0
        while new_time <= 0.0:
            new_time = np.random.normal(mean_growth_time, 0.4**2,1)[0]
        growth_time.append(new_time + min_time)
        
        
        time_points.append(min_time)
        number_of_cells.append(current_cells)

        number_of_cells.append(current_cells + 1)
        t = min_time
        time_points.append(t)
    return time_points, number_of_cells

# perform the simulation 100 times and plot the results
simulation_data = []
for i in range(100):
    time_points, number_of_cells = simulate_stochastic_growth(mean_growth_time=1.0, total_time=10.0)
    # consolodate the data to the compute the mean curves later
    simulation_data.append({
        "time": time_points,
        "cells": number_of_cells
    })
    # plt.plot(time_points, number_of_cells, color='purple', alpha=0.1)

# find the max time that is common across all simulations (since they will have different time points due to the stochasticity)
t_min = max(d["time"][0] for d in simulation_data)
t_max = min(d["time"][-1] for d in simulation_data)
# interpolate the curves to a common time grid and compute the mean curve
common_time = np.linspace(t_min, t_max, 200)
cells_mat = np.vstack([np.interp(common_time, d["time"], d["cells"]) for d in simulation_data])
mean_cells = np.mean(cells_mat, axis=0)

theoretical_time_points = np.linspace(0, 10, 200)
theoretical_cell_counts = np.exp(theoretical_time_points * np.log(2))
plt.figure(figsize=(8,6))
plt.plot(theoretical_time_points, theoretical_cell_counts, color='red', linestyle=':', label='Theoretical Exponential Growth')

colors =[ (248/255, 218/255, 152/255),
          (189/255, 85/255, 34/255),
          (0/255, 0/255, 0/255),
          (100/255, 180/255, 194/255)]
framework_labels = ['Chaste', 'PhysiCell', 'PolyHoop', 'TST']
iteration = 0
for framework in framework_labels:
    common_t, cells_rel_mean, _, _, _, simulation_data = clean_time_series_data_and_calculate_mean(framework, f'data/timeSeries/{framework}_MonolayerGrowth_1000_Data/')

    # for sim_index, sim_data in enumerate(simulation_data):
    #     # plot the raw curves for this simulation with low alpha
    #     plt.plot(sim_data["time"], sim_data["cells_rel"], color='black', alpha=0.15)
        
    # mean curves
    plt.plot(common_t, cells_rel_mean, color=colors[iteration], linewidth=2, label=framework_labels[iteration])
    iteration += 1

plt.plot(common_time, mean_cells, color='black', linestyle='--', label='Mean Stochastic Growth')

plt.xlabel('Mean Generational Time', fontsize=14)
plt.ylabel('Number of Cells', fontsize=14)
plt.title('Stochastic Growth Simulation', fontsize=16)
plt.grid(True)
plt.legend(fontsize=12)
plt.yscale('log')
plt.show()
# Out:
# Processing simulation 0 for framework Chaste...
# Processing simulation 1 for framework Chaste...
# Processing simulation 2 for framework Chaste...
# Processing simulation 3 for framework Chaste...
# Processing simulation 4 for framework Chaste...
# Processing simulation 5 for framework Chaste...
# Processing simulation 6 for framework Chaste...
